# %%
import pandas as pd
import numpy as np 
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Diuresis_TS.csv')

# %%
df.head()
# Out:
#    people_ID  20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  \
# 0          1        441        544        670        821       1002
# 1          2        151        197        253        322        400
# 2          3        416        515        632        777        948
# 3          4        410        506        621        762        928
# 4          5        390        483        595        730        893
#
#    25-Mar-20  26-Mar-20
# 0       1216       1473
# 1        493        607
# 2       1150       1396
# 3       1127       1368
# 4       1084       1316

# %%
df
# Out:
#        people_ID  20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  \
# 0              1        441        544        670        821       1002
# 1              2        151        197        253        322        400
# 2              3        416        515        632        777        948
# 3              4        410        506        621        762        928
# 4              5        390        483        595        730        893
# ...          ...        ...        ...        ...        ...        ...
# 10709      22691        134        174        225        288        359
# 10710      22692        387        479        592        725        885
# 10711      22693        177        228        288        362        448
# 10712      22694        352        438        543        666        815
# 10713      22695        181        230        290        366        455
#
#        25-Mar-20  26-Mar-20
# 0           1216       1473
# 1            493        607
# ...

# %%
key = df.keys()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 8 columns):
# people_ID    10714 non-null int64
# 20-Mar-20    10714 non-null int64
# 21-Mar-20    10714 non-null int64
# 22-Mar-20    10714 non-null int64
# 23-Mar-20    10714 non-null int64
# 24-Mar-20    10714 non-null int64
# 25-Mar-20    10714 non-null int64
# 26-Mar-20    10714 non-null int64
# dtypes: int64(8)
# memory usage: 669.8 KB

# %%
key
# Out:
# Index(['people_ID', '20-Mar-20', '21-Mar-20', '22-Mar-20', '23-Mar-20',
#        '24-Mar-20', '25-Mar-20', '26-Mar-20'],
#       dtype='object')

# %%
dataset = df.iloc[:,:]
dataset
# Out:
#        people_ID  20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  \
# 0              1        441        544        670        821       1002
# 1              2        151        197        253        322        400
# 2              3        416        515        632        777        948
# 3              4        410        506        621        762        928
# 4              5        390        483        595        730        893
# ...          ...        ...        ...        ...        ...        ...
# 10709      22691        134        174        225        288        359
# 10710      22692        387        479        592        725        885
# 10711      22693        177        228        288        362        448
# 10712      22694        352        438        543        666        815
# 10713      22695        181        230        290        366        455
#
#        25-Mar-20  26-Mar-20
# 0           1216       1473
# 1            493        607
# ...

# %%
dataset = dataset.iloc[:,1:]
dataset
# Out:
#        20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  25-Mar-20  \
# 0            441        544        670        821       1002       1216
# 1            151        197        253        322        400        493
# 2            416        515        632        777        948       1150
# 3            410        506        621        762        928       1127
# 4            390        483        595        730        893       1084
# ...          ...        ...        ...        ...        ...        ...
# 10709        134        174        225        288        359        444
# 10710        387        479        592        725        885       1075
# 10711        177        228        288        362        448        551
# 10712        352        438        543        666        815        991
# 10713        181        230        290        366        455        559
#
#        26-Mar-20
# 0           1473
# 1            607
# 2           1396
# 3           1368
# ...

# %%
forecast_out = 1
dataset['Prediction'] = dataset.iloc[:,-forecast_out]

# %%
X = np.array(dataset.drop(['Prediction'],1))

# %%
X = X[:,:-forecast_out]

# %%
X
# Out:
# array([[ 441,  544,  670,  821, 1002, 1216],
#        [ 151,  197,  253,  322,  400,  493],
#        [ 416,  515,  632,  777,  948, 1150],
#        ...,
#        [ 177,  228,  288,  362,  448,  551],
#        [ 352,  438,  543,  666,  815,  991],
#        [ 181,  230,  290,  366,  455,  559]], dtype=int64)

# %%
y = np.array(dataset['Prediction'])

# %%
y = np.array(dataset['Prediction'])

# %%
y
# Out:
# array([1473,  607, 1396, ...,  677, 1204,  687], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
svr = SVR( C=1e3, gamma='scale')

# %%
svr.fit(X_train, y_train)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svm_confidence= (svr.score(X_test, y_test))

# %%
svm_confidence
# Out:
# 0.9999888463201607

# %%
dd = df.iloc[:,2:]

# %%
dd
# Out:
#        21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  25-Mar-20  26-Mar-20
# 0            544        670        821       1002       1216       1473
# 1            197        253        322        400        493        607
# 2            515        632        777        948       1150       1396
# 3            506        621        762        928       1127       1368
# 4            483        595        730        893       1084       1316
# ...          ...        ...        ...        ...        ...        ...
# 10709        174        225        288        359        444        549
# 10710        479        592        725        885       1075       1303
# 10711        228        288        362        448        551        677
# 10712        438        543        666        815        991       1204
# 10713        230        290        366        455        559        687
#
# [10714 rows x 6 columns]

# %%
predict_for_27 = []

for i in range(0,len(dd)):
    f = dd.iloc[i:i+1,:]
    predict_for_27.append(int(svr.predict(f)))

# %%
df
# Out:
#        people_ID  20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  \
# 0              1        441        544        670        821       1002
# 1              2        151        197        253        322        400
# 2              3        416        515        632        777        948
# 3              4        410        506        621        762        928
# 4              5        390        483        595        730        893
# ...          ...        ...        ...        ...        ...        ...
# 10709      22691        134        174        225        288        359
# 10710      22692        387        479        592        725        885
# 10711      22693        177        228        288        362        448
# 10712      22694        352        438        543        666        815
# 10713      22695        181        230        290        366        455
#
#        25-Mar-20  26-Mar-20
# 0           1216       1473
# 1            493        607
# ...

# %%
df["27-Mar-20"] = (predict_for_27)

# %%
df
# Out:
#        people_ID  20-Mar-20  21-Mar-20  22-Mar-20  23-Mar-20  24-Mar-20  \
# 0              1        441        544        670        821       1002
# 1              2        151        197        253        322        400
# 2              3        416        515        632        777        948
# 3              4        410        506        621        762        928
# 4              5        390        483        595        730        893
# ...          ...        ...        ...        ...        ...        ...
# 10709      22691        134        174        225        288        359
# 10710      22692        387        479        592        725        885
# 10711      22693        177        228        288        362        448
# 10712      22694        352        438        543        666        815
# 10713      22695        181        230        290        366        455
#
#        25-Mar-20  26-Mar-20  27-Mar-20
# 0           1216       1473       1632
# ...

# %%
separate = ['people_ID','27-Mar-20']
df[separate].to_csv('27-March.csv', index=False)

# %%
_20_March = pd.read_csv('27-March.csv')

# %%
_20_March
# Out:
#        people_ID  27-Mar-20
# 0              1       1632
# 1              2        742
# 2              3       1633
# 3              4       1619
# 4              5       1580
# ...          ...        ...
# 10709      22691        672
# 10710      22692       1569
# 10711      22693        825
# 10712      22694       1459
# 10713      22695        837
#
# [10714 rows x 2 columns]
